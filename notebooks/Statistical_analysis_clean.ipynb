# %%
import json
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# This code block analyzes hallucination rates in AI-generated bibliographies
# from a JSONL file containing metadata for multiple papers.

# Load the JSONL file where each line is a JSON object representing a paper's metadata
with open("full_bibliography_metadata_qwen_3.jsonl", "r", encoding="utf-8") as f:
    results = [json.loads(line) for line in f]

# Initialize lists to store extracted data for each paper
hallucinations = []       # Estimated count of hallucinated references per paper
hallucination_rates = []  # Hallucination rate (fraction of references hallucinated)
years = []                # Publication year of the paper
titles = []               # Title of the paper

# Loop through each paper's metadata to extract relevant information
for paper in results:
    hr = paper.get('hallucination_rate')             # Fraction of hallucinated references
    bibliography = paper.get('generated_bibliography', [])  # List of generated references
    y = paper.get('year')                             # Publication year
    t = paper.get('title', 'Unknown Title')          # Paper title, default if missing

    # Check if hallucination rate is present and bibliography is a non-empty list
    if hr is not None and isinstance(bibliography, list) and len(bibliography) > 0:
        # Calculate the estimated hallucinated references count by multiplying
        # hallucination rate by number of references, then rounding
        h = round(hr * len(bibliography))
        hallucinations.append(h)
        hallucination_rates.append(hr)
        years.append(y)
        titles.append(t)

# Create a DataFrame from the collected data for easier analysis
df = pd.DataFrame({
    'title': titles,
    'year': years,
    'hallucinations': hallucinations,
    'hallucination_rate': hallucination_rates
})

# Print summary statistics for hallucinated reference counts
print("=== Hallucinations Count Summary ===")
print(df['hallucinations'].describe())

# Print summary statistics for hallucination rates
print("\n=== Hallucination Rate Summary ===")
print(df['hallucination_rate'].describe())

# Plot 1: Histogram showing distribution of hallucinated reference counts across papers
plt.figure(figsize=(10, 5))
plt.hist(df['hallucinations'], bins=30, color='skyblue', edgecolor='black')
plt.title("Histogram of Hallucinated References")
plt.xlabel("Estimated Hallucinated References")
plt.ylabel("Number of Papers")
plt.grid(True)
plt.tight_layout()
plt.show()

# Plot 2: Histogram showing distribution of hallucination rates across papers
plt.figure(figsize=(10, 5))
plt.hist(df['hallucination_rate'], bins=30, color='salmon', edgecolor='black')
plt.title("Histogram of Hallucination Rate")
plt.xlabel("Hallucination Rate")
plt.ylabel("Number of Papers")
plt.grid(True)
plt.tight_layout()
plt.show()

# Plot 3: Line plot of average hallucination rate per publication year (if year data available)
if df['year'].notna().sum() > 0:
    # Group data by year and compute mean hallucination rate for each year
    df_yearly = df.groupby('year')['hallucination_rate'].mean().reset_index()
    plt.figure(figsize=(10, 5))
    plt.plot(df_yearly['year'], df_yearly['hallucination_rate'], marker='o', linestyle='-')
    plt.title("Average Hallucination Rate by Year")
    plt.xlabel("Year")
    plt.ylabel("Average Hallucination Rate")
    plt.grid(True)
    plt.tight_layout()
    plt.show()

# Identify and display top 10 papers with the highest hallucination rates
top_papers = df.sort_values(by='hallucination_rate', ascending=False).head(10)
print("\n=== Top 10 Papers by Hallucination Rate ===")
print(top_papers[['title', 'hallucinations', 'hallucination_rate']])
# Out:
# === Hallucinations Count Summary ===
# count    83.000000
# mean      3.855422
# std       1.380461
# min       1.000000
# 25%       3.000000
# 50%       4.000000
# 75%       5.000000
# max       8.000000
# Name: hallucinations, dtype: float64
#
# === Hallucination Rate Summary ===
# count    83.000000
# mean      0.571827
# std       0.198209
# min       0.066667
# 25%       0.408333
# 50%       0.578947
# 75%       0.725000
# max       0.950000
# Name: hallucination_rate, dtype: float64
# === Top 10 Papers by Hallucination Rate ===
#                                                 title  hallucinations  \
# 19  Triboelectric tactile sensor for pressure and ...               1
# 60  Unlocking Mechanisms for Soil Organic Matter A...               1
# 50  Leveraging artificial intelligence and advance...               1
# 63  Unlocking the potential of banana peel bioacti...               1
# 64  Design prognostics for 4400 TEU container vess...               2
# 25  Security and Privacy Challenges of Large Langu...               2
# 78  From digital corporate social responsibility (...               3
# 26  Realization of p-type MA-based perovskite sola...               3
# 35  Sacrificing patient care for prevention: disto...               2
# 48  Dark Matter Search Results from <mml:math xmln...               2
#
#     hallucination_rate
# 19            0.950000
# 60            0.950000
# 50            0.947368
# 63            0.933333
# 64            0.866667
# 25            0.857143
# 78            0.850000
# 26            0.850000
# 35            0.800000
# 48            0.800000

# %%
import json
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import mannwhitneyu

# This code analyzes and compares citation counts of references from
# real bibliographies and AI-generated bibliographies across papers.

# Load the full metadata JSONL file where each line contains a paper's metadata
with open("full_bibliography_metadata_qwen_3.jsonl", "r", encoding="utf-8") as f:
    results = [json.loads(line) for line in f]

# Initialize lists to store citation counts from real and generated bibliographies
real_cited_citations = []
gen_cited_citations = []

# Loop through each paper's metadata
for entry in results:
    # Extract citation counts from the 'real_bibliography' if available and valid (>0)
    for ref in entry.get('real_bibliography', []):
        cit_count = ref.get('citation_count')
        if cit_count is not None and cit_count > 0:
            real_cited_citations.append(cit_count)

    # Extract citation counts from the 'generated_bibliography' if available and valid (>0)
    for ref in entry.get('generated_bibliography', []):
        cit_count = ref.get('citation_count')
        if cit_count is not None and cit_count > 0:
            gen_cited_citations.append(cit_count)

# Print the total number of citation counts collected from each bibliography type
print(f"Collected {len(real_cited_citations)} citation counts from real bibliographies.")
print(f"Collected {len(gen_cited_citations)} citation counts from generated bibliographies.")

# Compute and print basic statistics: mean, median, and standard deviation of citation counts
print(f"Real cited papers - mean: {np.mean(real_cited_citations):.2f}, median: {np.median(real_cited_citations)}, std: {np.std(real_cited_citations):.2f}")
print(f"Generated cited papers - mean: {np.mean(gen_cited_citations):.2f}, median: {np.median(gen_cited_citations)}, std: {np.std(gen_cited_citations):.2f}")

# Apply log10 transformation to citation counts to reduce skewness and make distributions more comparable
real_log = np.log10(real_cited_citations)
gen_log = np.log10(gen_cited_citations)

# Plot histogram with KDE (Kernel Density Estimate) overlay for both real and generated citation counts (log scale)
plt.figure(figsize=(12, 6))
# Define common bins for both datasets for better comparison
bins = np.linspace(min(real_log.min(), gen_log.min()), max(real_log.max(), gen_log.max()), 40)

# Plot histogram + KDE for real cited papers (blue, semi-transparent)
sns.histplot(real_log, bins=bins, kde=True, stat='density', label='Real cited papers', color='blue', alpha=0.5)

# Plot histogram + KDE for generated cited papers (orange, semi-transparent)
sns.histplot(gen_log, bins=bins, kde=True, stat='density', label='Generated cited papers', color='orange', alpha=0.5)

# Set plot labels and title
plt.xlabel('log10(Citation count)')
plt.ylabel('Density')
plt.title('Citation count distribution (log10 scale)')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# Perform Mann-Whitney U test (non-parametric) to test whether the two citation count distributions differ significantly
# Use raw citation counts (not log-transformed) for the test
stat, p_value = mannwhitneyu(real_cited_citations, gen_cited_citations, alternative='two-sided')

# Print test statistic and p-value
print(f"Mann-Whitney U test statistic: {stat}")
print(f"P-value: {p_value:.4f}")

# Interpret the p-value with standard 0.05 significance level threshold
if p_value < 0.05:
    print("Significant difference in citation count distributions of cited papers.")
else:
    print("No significant difference found in citation count distributions of cited papers.")
# Out:
# Collected 7932 citation counts from real bibliographies.
# Collected 648 citation counts from generated bibliographies.
# Real cited papers - mean: 1215.49, median: 87.0, std: 10533.70
# Generated cited papers - mean: 6969.33, median: 1825.5, std: 15082.48
# Mann-Whitney U test statistic: 849213.0
# P-value: 0.0000
# Significant difference in citation count distributions of cited papers.

# %%
from scipy.stats import skew, kurtosis

print(f"Skewness (real): {skew(real_cited_citations):.2f}")
print(f"Kurtosis (real): {kurtosis(real_cited_citations, fisher=True):.2f}")

print(f"Skewness (generated): {skew(gen_cited_citations):.2f}")
print(f"Kurtosis (generated): {kurtosis(gen_cited_citations, fisher=True):.2f}")
# Out:
# Skewness (real): 23.88
# Kurtosis (real): 673.19
# Skewness (generated): 5.02
# Kurtosis (generated): 39.03

# %%
def plot_ccdf(data, label):
    sorted_data = np.sort(data)
    ccdf = 1. - np.arange(1, len(data)+1) / len(data)
    plt.loglog(sorted_data, ccdf, label=label)

plt.figure(figsize=(10, 6))
plot_ccdf(real_cited_citations, "Real")
plot_ccdf(gen_cited_citations, "Generated")
plt.xlabel("Citation count")
plt.ylabel("CCDF (P(X > x))")
plt.title("CCDF of citation counts (log-log)")
plt.legend()
plt.grid(True, which="both", ls="--")
plt.tight_layout()
plt.show()

# %%
import powerlaw

fit_real = powerlaw.Fit(real_cited_citations)
print(f"Estimated alpha (real): {fit_real.alpha:.2f}")
print(f"Power-law xmin (real): {fit_real.xmin}")

fit_gen = powerlaw.Fit(gen_cited_citations)
print(f"Estimated alpha (generated): {fit_gen.alpha:.2f}")
print(f"Power-law xmin (generated): {fit_gen.xmin}")
# Out:
# Calculating best minimal value for power law fit
# Estimated alpha (real): 1.70
# Power-law xmin (real): 241.0
# Calculating best minimal value for power law fit
# Estimated alpha (generated): 2.28
# Power-law xmin (generated): 12399.0

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# Initialize lists to hold publication years from real and generated bibliographies
real_years = []
gen_years = []

# Loop through each paper's metadata to extract publication years of cited references
for entry in results:
    # Extract publication years from real bibliographies if available
    for ref in entry.get('real_bibliography', []):
        year = ref.get('year')
        if year is not None:  # Only consider valid years (not None)
            real_years.append(year)

    # Extract publication years from generated bibliographies if available
    for ref in entry.get('generated_bibliography', []):
        year = ref.get('year')
        if year is not None:
            gen_years.append(year)

# At this point, real_years and gen_years contain publication years of cited references
# from the real and generated bibliographies, respectively.

# Plotting the distribution of publication years of cited papers from both real and generated bibliographies
plt.figure(figsize=(12, 5))

# Create bins for the histogram spanning the full range of years found in both datasets
bins = np.arange(min(real_years + gen_years), max(real_years + gen_years) + 1)

# Plot histogram (density normalized) for real cited paper publication years
sns.histplot(real_years, bins=bins, kde=False, stat='density',
             label='Real cited papers', color='blue', alpha=0.5)

# Plot histogram (density normalized) for generated cited paper publication years
sns.histplot(gen_years, bins=bins, kde=False, stat='density',
             label='Generated cited papers', color='orange', alpha=0.5)

# Label the axes and set plot title
plt.xlabel('Publication year')
plt.ylabel('Density')
plt.title('Publication year distribution of cited papers')

# Add legend to distinguish between real and generated data
plt.legend()

# Add grid for easier reading of the plot
plt.grid(True)

# Adjust layout to avoid clipping elements
plt.tight_layout()

# Display the plot
plt.show()

# %%
# Check for papers cited with publication year 1825
target_year = 1823

for entry in results:
    for ref in entry.get('real_bibliography', []):
        if ref.get('year') == target_year:
            print("Real bibliography paper from 1825 found:")
            print(json.dumps(ref, indent=2))
    for ref in entry.get('generated_bibliography', []):
        if ref.get('year') == target_year:
            print("Generated bibliography paper from 1825 found:")
            print(json.dumps(ref, indent=2))
# Out:
# Real bibliography paper from 1825 found:
# {
#   "title": "MR. SCOTT'S REPLY TO MR. ALCOCK.",
#   "authors": [
#     {
#       "name": "NA NA",
#       "id": "https://openalex.org/A5065421650"
#     }
#   ],
#   "year": 1823,
#   "venue": "The Lancet",
#   "citation_count": 119
# }

# %%
import pandas as pd
import numpy as np

# Define a function that computes summary statistics for a list/array of years
def summarize_years(years):
    return {
        'mean': np.mean(years),               # Average publication year
        'median': np.median(years),           # Median publication year
        'std': np.std(years),                 # Standard deviation (spread) of years
        'min': np.min(years),                 # Earliest publication year
        'max': np.max(years),                 # Latest publication year
        '25%': np.percentile(years, 25),     # 25th percentile (first quartile)
        '75%': np.percentile(years, 75),     # 75th percentile (third quartile)
        'IQR': np.percentile(years, 75) - np.percentile(years, 25)  # Interquartile range (spread of middle 50%)
    }

# Compute summary statistics for real cited paper years
real_summary = summarize_years(real_years)

# Compute summary statistics for generated cited paper years
gen_summary = summarize_years(gen_years)

# Combine both summaries into a DataFrame with 'Real' and 'Generated' as columns
summary_df = pd.DataFrame({'Real': real_summary, 'Generated': gen_summary})

# Transpose the DataFrame so the metrics become rows and bibliography types become columns
summary_df = summary_df.T

# Print the resulting summary statistics table
print(summary_df)
# Out:
#                   mean  median        std     min     max     25%     75%  \
# Real       2015.438422  2019.0  11.362456  1823.0  2025.0  2013.0  2022.0
# Generated  2005.351310  2010.0  15.268420  1924.0  2025.0  1998.0  2017.0
#
#             IQR
# Real        9.0
# Generated  19.0

# %%
"""
This script analyzes the similarity between real and AI-generated bibliographies 
for a collection of research papers. 

It reads a JSONL file where each entry contains metadata for a paper, including 
its real bibliography and a generated bibliography. For each paper, it extracts 
the titles from both bibliographies, normalizes them, and computes similarity metrics 
between the two sets of titles: the Jaccard similarity and the Overlap coefficient. 

Finally, it summarizes the similarity metrics over all papers and visualizes the 
distribution of the Jaccard similarity scores using a histogram.
"""

import json
import pandas as pd
import re
import matplotlib.pyplot as plt

# Load the JSONL file containing metadata for papers including their real and generated bibliographies
with open("full_bibliography_metadata_qwen_3.jsonl", "r", encoding="utf-8") as f:
    results = [json.loads(line) for line in f]

# Function to normalize titles:
# - lowercase all letters
# - trim leading/trailing whitespace
# - collapse multiple spaces to a single space
# - remove punctuation characters for consistency
def normalize_title(title):
    title = title.lower().strip()
    title = re.sub(r'\s+', ' ', title)  # Normalize whitespace to single spaces
    title = re.sub(r'[^\w\s]', '', title)  # Remove punctuation (anything that's not word or space)
    return title

# Compute Jaccard similarity between two sets:
# Jaccard similarity = (size of intersection) / (size of union)
def jaccard_similarity(set1, set2):
    intersection = len(set1.intersection(set2))
    union = len(set1.union(set2))
    return intersection / union if union != 0 else 0

# Compute Overlap Coefficient between two sets:
# Overlap coefficient = (size of intersection) / (size of smaller set)
def overlap_coefficient(set1, set2):
    intersection = len(set1.intersection(set2))
    min_size = min(len(set1), len(set2))
    return intersection / min_size if min_size != 0 else 0

results_metrics = []  # List to store similarity metrics for each paper

# For each paper entry in the dataset...
for entry in results:
    # Extract and normalize titles from real bibliography, skipping entries without titles
    real_titles = set(
        normalize_title(ref.get('title', '')) 
        for ref in entry.get('real_bibliography', []) 
        if ref.get('title')
    )
    # Extract and normalize titles from generated bibliography, skipping entries without titles
    gen_titles = set(
        normalize_title(ref.get('title', '')) 
        for ref in entry.get('generated_bibliography', []) 
        if ref.get('title')
    )
    
    # Calculate size of intersection and union of real and generated title sets
    inter = len(real_titles.intersection(gen_titles))
    union = len(real_titles.union(gen_titles))
    
    # Calculate Jaccard similarity and overlap coefficient between title sets
    jaccard = jaccard_similarity(real_titles, gen_titles)
    overlap = overlap_coefficient(real_titles, gen_titles)
    
    # Store metrics along with paper identifier and size info for later analysis
    results_metrics.append({
        'paper_id': entry.get('paper_id', None),
        'real_size': len(real_titles),  # Number of unique titles in real bibliography
        'gen_size': len(gen_titles),    # Number of unique titles in generated bibliography
        'intersection': inter,           # Number of titles common to both sets
        'union': union,                  # Number of unique titles in either set
        'jaccard': jaccard,              # Jaccard similarity score
        'overlap': overlap               # Overlap coefficient score
    })

# Convert the list of dictionaries into a Pandas DataFrame for easier analysis
df_metrics = pd.DataFrame(results_metrics)

# Print summary statistics (count, mean, std, min, max, quartiles) for all computed metrics
print(df_metrics.describe())

# Plot a histogram of the Jaccard similarity scores across all papers
plt.hist(df_metrics['jaccard'], bins=30, alpha=0.7)
plt.xlabel('Jaccard similarity')
plt.ylabel('Number of papers')
plt.title('Distribution of Jaccard similarity between real and generated bibliographies')
plt.show()
# Out:
#         paper_id   real_size   gen_size  intersection       union    jaccard  \
# count  99.000000   99.000000  99.000000     99.000000   99.000000  99.000000
# mean   49.616162   79.727273   6.434343      0.616162   85.545455   0.008618
# std    29.135751  107.378961   4.531436      1.075773  106.991634   0.013685
# min     0.000000    3.000000   0.000000      0.000000    5.000000   0.000000
# 25%    24.500000   25.500000   3.000000      0.000000   32.000000   0.000000
# 50%    50.000000   50.000000   7.000000      0.000000   58.000000   0.000000
# 75%    74.500000   93.000000  10.000000      1.000000   96.000000   0.016878
# max    99.000000  859.000000  15.000000      7.000000  864.000000   0.052632
#
#          overlap
# count  99.000000
# mean    0.095013
# std     0.187474
# min     0.000000
# 25%     0.000000
# 50%     0.000000
# 75%     0.125000
# max     1.000000

# %%
"""
This script analyzes and compares the distribution of the number of cited papers 
per bibliography across three categories: 

1. Real bibliographies (actual cited papers),
2. Generated bibliographies' non-hallucinated citations (those considered accurate),
3. Generated bibliographies' hallucinated citations (fabricated or incorrect citations).

It visualizes these distributions with density histograms, allowing us to see 
how the number of cited papers differs between real references and AI-generated ones, 
including a combined view of all generated citations.
"""

import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

real_num_cited = []
gen_num_non_hallucinated = []
gen_num_hallucinated = []

# Iterate over each paper entry in the dataset
for entry in results:
    # Extract the list of real cited references and count them
    real_refs = entry.get('real_bibliography', [])
    real_num_cited.append(len(real_refs))

    # Extract the list of generated references and hallucination rate
    gen_refs = entry.get('generated_bibliography', [])
    halluc_rate = entry.get('hallucination_rate', 0.0)  # Defaults to 0 if missing
    total_gen = len(gen_refs)

    # Calculate the number of hallucinated and non-hallucinated references
    num_hall = int(round(halluc_rate * total_gen))
    num_non_hall = total_gen - num_hall

    # Store counts in their respective lists
    gen_num_hallucinated.append(num_hall)
    gen_num_non_hallucinated.append(num_non_hall)


# Plot 1: Histogram comparing distributions of real, generated non-hallucinated, and hallucinated citations
plt.figure(figsize=(12, 6))

# Define bins for the histogram to cover range of citation counts across all groups
bins = np.arange(0, max(
    max(real_num_cited, default=0),
    max(gen_num_non_hallucinated, default=0),
    max(gen_num_hallucinated, default=0)
) + 2) - 0.5  # Shift bins by 0.5 for better alignment of integer counts on x-axis

plt.xlim(0, 50)  # Limit x-axis to a max of 50 for clearer visualization

# Plot real citations distribution
sns.histplot(real_num_cited, bins=bins, kde=False, stat='density',
             label='Real cited papers', color='blue', alpha=0.5)

# Plot generated non-hallucinated citations distribution
sns.histplot(gen_num_non_hallucinated, bins=bins, kde=False, stat='density',
             label='Generated non-hallucinated papers', color='green', alpha=0.5)

# Plot generated hallucinated citations distribution
sns.histplot(gen_num_hallucinated, bins=bins, kde=False, stat='density',
             label='Generated hallucinated papers', color='red', alpha=0.5)

plt.xlabel('Number of papers per bibliography')
plt.ylabel('Density')
plt.title('Distribution of number of papers per bibliography')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()


# Combine hallucinated and non-hallucinated generated citations into a single list
gen_all = gen_num_non_hallucinated + gen_num_hallucinated

# Plot 2: Histogram comparing real citations vs all generated citations combined
plt.figure(figsize=(12, 6))

# Define bins based on the max counts across real and combined generated citations
bins = np.arange(0, max(
    max(real_num_cited, default=0),
    max(gen_all, default=0)
) + 2) - 0.5

plt.xlim(0, 50)

# Plot real citations distribution
sns.histplot(real_num_cited, bins=bins, kde=False, stat='density',
             label='Real cited papers', color='blue', alpha=0.5)

# Plot all generated citations distribution (hallucinated + non-hallucinated)
sns.histplot(gen_all, bins=bins, kde=False, stat='density',
             label='All generated papers (hallucinated + non-hallucinated)', color='orange', alpha=0.5)

plt.xlabel('Number of papers per bibliography')
plt.ylabel('Density')
plt.title('Distribution of number of papers per bibliography: Real vs All Generated')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
"""
This script loads author gender metadata from a JSONL dataset containing 
both real and AI-generated bibliographies. It analyzes the gender distribution 
of authors by counting male, female, and unknown gender labels in both real and generated bibliographies.

The script computes overall gender proportions (including unknowns) and also focuses on known genders only,
calculating 95% confidence intervals for the proportions.

Finally, it visualizes the distributions in bar plots for both the full dataset (all authors)
and the subset with known genders only, providing a comparative view of real vs generated bibliographies.
"""

import json
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from collections import Counter

# --- Load JSONL file ---
with open("full_bibliography_metadata_qwen_3.jsonl", "r", encoding="utf-8") as f:
    results = [json.loads(line) for line in f]

# --- Helper function to count genders from author metadata ---
def count_genders(author_metadata):
    """
    Counts occurrences of gender categories ('male', 'female', 'unknown') in a list of authors.

    Parameters:
        author_metadata (list): List of dictionaries with author info, including a 'gender' key.

    Returns:
        Counter: Counts of genders found in the author list.
    """
    counter = Counter()
    for author in author_metadata:
        # Use lowercase to normalize gender strings, defaulting to 'unknown' if missing
        gender = author.get("gender", "unknown").lower()
        counter[gender] += 1
    return counter

# --- Aggregate gender counts for all papers ---
all_gender_data = []

for entry in results:
    paper_id = entry.get("paper_id")

    # Extract author metadata for real and generated bibliographies
    real_authors = entry.get("real_analysis", {}).get("author_metadata", [])
    gen_authors = entry.get("generated_analysis", {}).get("author_metadata", [])

    # Count genders in both real and generated authorship lists
    real_gender_counts = count_genders(real_authors)
    gen_gender_counts = count_genders(gen_authors)

    # Append aggregated counts per paper to a list for DataFrame creation
    all_gender_data.append({
        "paper_id": paper_id,
        "real_male": real_gender_counts.get("male", 0),
        "real_female": real_gender_counts.get("female", 0),
        "real_unknown": real_gender_counts.get("unknown", 0),
        "gen_male": gen_gender_counts.get("male", 0),
        "gen_female": gen_gender_counts.get("female", 0),
        "gen_unknown": gen_gender_counts.get("unknown", 0),
    })

# Convert list of dictionaries to a DataFrame for convenient analysis
gender_df = pd.DataFrame(all_gender_data)

# --- Compute totals across all papers ---
totals = {
    "real": gender_df[["real_male", "real_female", "real_unknown"]].sum(),
    "generated": gender_df[["gen_male", "gen_female", "gen_unknown"]].sum()
}

# --- Compute percentage distributions including unknown gender category ---
def compute_percentages(counts):
    """
    Computes percentage share of each gender category given counts.

    Parameters:
        counts (dict): Counts of gender categories.

    Returns:
        dict: Percentage of each category (sum to 100% if total > 0).
    """
    total = sum(counts.values())
    return {k: (v / total * 100 if total > 0 else 0) for k, v in counts.items()}

real_percent_all = compute_percentages(totals["real"].to_dict())
gen_percent_all = compute_percentages(totals["generated"].to_dict())

# --- Function to calculate 95% confidence intervals for proportions ---
def proportion_ci(k, n, confidence=0.95):
    """
    Calculates proportion and its confidence interval using normal approximation.

    Parameters:
        k (int): Count of successes (e.g., male authors).
        n (int): Total number of trials (e.g., all known gender authors).
        confidence (float): Confidence level (default 0.95).

    Returns:
        tuple: (proportion_percent, lower_bound_percent, upper_bound_percent)
    """
    if n == 0:
        return 0, 0, 0
    p = k / n
    z = 1.96  # z-score for 95% confidence
    se = np.sqrt(p * (1 - p) / n)  # standard error
    lower = max(0, p - z * se)
    upper = min(1, p + z * se)
    return p * 100, lower * 100, upper * 100

# Extract counts of known gender authors (excluding unknown)
real_male = totals["real"]["real_male"]
real_female = totals["real"]["real_female"]
real_known_total = real_male + real_female

gen_male = totals["generated"]["gen_male"]
gen_female = totals["generated"]["gen_female"]
gen_known_total = gen_male + gen_female

# Calculate percentages and confidence intervals for known genders only
real_male_pct, real_male_lower, real_male_upper = proportion_ci(real_male, real_known_total)
real_female_pct, real_female_lower, real_female_upper = proportion_ci(real_female, real_known_total)

gen_male_pct, gen_male_lower, gen_male_upper = proportion_ci(gen_male, gen_known_total)
gen_female_pct, gen_female_lower, gen_female_upper = proportion_ci(gen_female, gen_known_total)

# --- Plot 1: Gender distribution including unknown authors ---
labels = ['Male', 'Female', 'Unknown']

real_vals_all = [real_percent_all.get("real_male", 0), real_percent_all.get("real_female", 0), real_percent_all.get("real_unknown", 0)]
gen_vals_all = [gen_percent_all.get("gen_male", 0), gen_percent_all.get("gen_female", 0), gen_percent_all.get("gen_unknown", 0)]

x = range(len(labels))
bar_width = 0.35

plt.figure(figsize=(8, 5))
plt.bar(x, real_vals_all, width=bar_width, label='Real', alpha=0.7)
plt.bar([i + bar_width for i in x], gen_vals_all, width=bar_width, label='Generated', alpha=0.7)
plt.xticks([i + bar_width / 2 for i in x], labels)
plt.ylabel('Percentage of Authors')
plt.title('Gender Distribution in Real vs Generated Bibliographies (All Authors)')
plt.legend()
plt.tight_layout()
plt.show()

# --- Plot 2: Known genders only with 95% confidence intervals ---
labels_known = ['Male', 'Female']
real_vals_known = [real_male_pct, real_female_pct]
real_err_known = [real_male_upper - real_male_pct, real_female_upper - real_female_pct]

gen_vals_known = [gen_male_pct, gen_female_pct]
gen_err_known = [gen_male_upper - gen_male_pct, gen_female_upper - gen_female_pct]

x_known = np.arange(len(labels_known))

plt.figure(figsize=(7, 5))
plt.bar(
    x_known,
    real_vals_known,
    width=bar_width,
    yerr=real_err_known,
    capsize=5,
    label='Real Bibliographies',
    alpha=0.7,
    color='skyblue',
)
plt.bar(
    x_known + bar_width,
    gen_vals_known,
    width=bar_width,
    yerr=gen_err_known,
    capsize=5,
    label='Generated Bibliographies',
    alpha=0.7,
    color='salmon',
)
plt.xticks(x_known + bar_width / 2, labels_known)
plt.ylabel('Percentage of Authors')
plt.title('Gender Distribution (Known Only) with 95% Confidence Intervals')
plt.ylim(0, 100)
plt.legend()
plt.tight_layout()
plt.show()

# --- Print summary tables ---
print("\n=== Gender Distribution (Total Counts) ===")
print("Real Bibliographies:", totals["real"].to_dict())
print("Generated Bibliographies:", totals["generated"].to_dict())

print("\n=== Gender Distribution (Percentages, All Authors) ===")
print("Real Bibliographies:", {k: f"{v:.2f}%" for k,v in real_percent_all.items()})
print("Generated Bibliographies:", {k: f"{v:.2f}%" for k,v in gen_percent_all.items()})

print("\n=== Gender Distribution (Percentages with 95% CI, Known Genders Only) ===")
print("Real Bibliographies:")
print(f"  Male:   {real_male_pct:.2f}% [{real_male_lower:.2f}%, {real_male_upper:.2f}%]")
print(f"  Female: {real_female_pct:.2f}% [{real_female_lower:.2f}%, {real_female_upper:.2f}%]\n")

print("Generated Bibliographies:")
print(f"  Male:   {gen_male_pct:.2f}% [{gen_male_lower:.2f}%, {gen_male_upper:.2f}%]")
print(f"  Female: {gen_female_pct:.2f}% [{gen_female_lower:.2f}%, {gen_female_upper:.2f}%]")
# Out:
# === Gender Distribution (Total Counts) ===
# Real Bibliographies: {'real_male': 2479, 'real_female': 1066, 'real_unknown': 3143}
# Generated Bibliographies: {'gen_male': 592, 'gen_female': 190, 'gen_unknown': 572}
#
# === Gender Distribution (Percentages, All Authors) ===
# Real Bibliographies: {'real_male': '37.07%', 'real_female': '15.94%', 'real_unknown': '46.99%'}
# Generated Bibliographies: {'gen_male': '43.72%', 'gen_female': '14.03%', 'gen_unknown': '42.25%'}
#
# === Gender Distribution (Percentages with 95% CI, Known Genders Only) ===
# Real Bibliographies:
#   Male:   69.93% [68.42%, 71.44%]
#   Female: 30.07% [28.56%, 31.58%]
#
# Generated Bibliographies:
#   Male:   75.70% [72.70%, 78.71%]
#   Female: 24.30% [21.29%, 27.30%]

# %%
import json
import requests
import time
from concurrent.futures import ThreadPoolExecutor, as_completed
import matplotlib.pyplot as plt
import seaborn as sns

def get_author_openalex_id(name):
    url = f"https://api.openalex.org/authors?search={name}&per-page=1"
    try:
        r = requests.get(url)
        r.raise_for_status()
        results = r.json().get('results', [])
        if results:
            return results[0]['id']
    except Exception as e:
        print(f"[ID Error] {name}: {e}")
    return None

def get_author_works_citations(openalex_id):
    url = f"https://api.openalex.org/works?filter=author.id:{openalex_id}&per-page=200"
    citations = []
    try:
        while url:
            r = requests.get(url)
            r.raise_for_status()
            data = r.json()
            for work in data['results']:
                if 'cited_by_count' in work:
                    citations.append(work['cited_by_count'])
            next_cursor = data['meta'].get('next_cursor')
            if next_cursor:
                url = f"https://api.openalex.org/works?filter=author.id:{openalex_id}&per-page=200&cursor={next_cursor}"
            else:
                url = None
            time.sleep(1)
    except Exception as e:
        print(f"[Works Error] {openalex_id}: {e}")
    return citations

def compute_h_index(citations):
    citations.sort(reverse=True)
    h = 0
    for i, c in enumerate(citations):
        if c >= i + 1:
            h = i + 1
        else:
            break
    return h

def process_author(author):
    openalex_id = get_author_openalex_id(author)
    if openalex_id:
        citations = get_author_works_citations(openalex_id)
        h_index = compute_h_index(citations)
        return author, h_index
    else:
        return author, None

# Load JSONL
real_authors = set()
generated_authors = set()
with open("full_bibliography_metadata_qwen_3.jsonl", "r", encoding="utf-8") as f:
    for line in f:
        paper = json.loads(line)
        real_authors.update(
            a["name"] for a in paper.get("real_analysis", {}).get("author_metadata", []) if "name" in a
        )
        generated_authors.update(
            a["name"] for a in paper.get("generated_analysis", {}).get("author_metadata", []) if "name" in a
        )

all_authors = list(real_authors.union(generated_authors))

author_hindex = {}

MAX_WORKERS = 5
with ThreadPoolExecutor(max_workers=MAX_WORKERS) as executor:
    futures = {executor.submit(process_author, author): author for author in all_authors}
    for future in as_completed(futures):
        author, h_index = future.result()
        author_hindex[author] = h_index
        #print(f"Processed {author} -> h-index: {h_index}")

# Save results to JSON file
with open("authors_hindex.json", "w", encoding="utf-8") as outfile:
    json.dump(author_hindex, outfile, indent=2, ensure_ascii=False)

# Prepare distributions
real_hindex = [author_hindex[a] for a in real_authors if author_hindex.get(a) is not None]
generated_hindex = [author_hindex[a] for a in generated_authors if author_hindex.get(a) is not None]

# Plotting
plt.figure(figsize=(10, 6))
sns.kdeplot(real_hindex, label="Real Authors", fill=True)
sns.kdeplot(generated_hindex, label="Generated Authors", fill=True)
plt.xlabel("H-index")
plt.ylabel("Density")
plt.title("H-index Distribution: Real vs Generated Authors (from OpenAlex, parallelized)")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# [ID Error] Lihong V. Wang: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Lihong%20V.%20Wang&per-page=1
# [ID Error] Kerry Haynes: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Kerry%20Haynes&per-page=1
# [Works Error] https://openalex.org/A5060967626: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/works?filter=author.id:https://openalex.org/A5060967626&per-page=200
# [ID Error] Kaiming He: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Kaiming%20He&per-page=1
# [ID Error] Franck Zinzindohoué: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Franck%20Zinzindohou%C3%A9&per-page=1
# [Works Error] https://openalex.org/A5107896153: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/works?filter=author.id:https://openalex.org/A5107896153&per-page=200
# [Works Error] https://openalex.org/A5018536426: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/works?filter=author.id:https://openalex.org/A5018536426&per-page=200
# [ID Error] P. Ajith: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=P.%20Ajith&per-page=1
# [ID Error] Nihad Alsmairat: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Nihad%20Alsmairat&per-page=1
# [ID Error] Sukhdeep Singh: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Sukhdeep%20Singh&per-page=1
# [ID Error] Eva Tomaskovic‐Crook: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Eva%20Tomaskovic%E2%80%90Crook&per-page=1
# [ID Error] Sergio Quevedo: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Sergio%20Quevedo&per-page=1
# [ID Error] R. Bajpai: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=R.%20Bajpai&per-page=1
# [ID Error] Xinjun Du: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Xinjun%20Du&per-page=1
# [ID Error] Fermín Cuevas: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Ferm%C3%ADn%20Cuevas&per-page=1
# [ID Error] David G. Castner: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=David%20G.%20Castner&per-page=1
# [Works Error] https://openalex.org/A5076142265: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/works?filter=author.id:https://openalex.org/A5076142265&per-page=200
# [Works Error] https://openalex.org/A5100348895: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/works?filter=author.id:https://openalex.org/A5100348895&per-page=200
# [Works Error] https://openalex.org/A5012615206: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/works?filter=author.id:https://openalex.org/A5012615206&per-page=200
# [ID Error] Ian J. Majewski: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Ian%20J.%20Majewski&per-page=1
# [ID Error] Yushan Qiao: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Yushan%20Qiao&per-page=1
# [ID Error] Yan Gong: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Yan%20Gong&per-page=1
# [Works Error] https://openalex.org/A5086477677: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/works?filter=author.id:https://openalex.org/A5086477677&per-page=200
# [Works Error] https://openalex.org/A5044928609: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/works?filter=author.id:https://openalex.org/A5044928609&per-page=200
# [Works Error] https://openalex.org/A5100769707: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/works?filter=author.id:https://openalex.org/A5100769707&per-page=200
# [ID Error] Albert P. Bartók: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Albert%20P.%20Bart%C3%B3k&per-page=1
# [ID Error] André Moura Kohmann: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Andr%C3%A9%20Moura%20Kohmann&per-page=1
# [ID Error] Raphael Alford: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Raphael%20Alford&per-page=1
# [ID Error] Tobias Kuhn: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Tobias%20Kuhn&per-page=1
# [ID Error] Yanyan Zhang: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Yanyan%20Zhang&per-page=1
# [Works Error] https://openalex.org/A5019342070: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/works?filter=author.id:https://openalex.org/A5019342070&per-page=200
# [Works Error] https://openalex.org/A5091411374: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/works?filter=author.id:https://openalex.org/A5091411374&per-page=200
# [Works Error] https://openalex.org/A5004515174: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/works?filter=author.id:https://openalex.org/A5004515174&per-page=200
# [ID Error] Hannah Douthwaite: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Hannah%20Douthwaite&per-page=1
# [ID Error] Andreas Goette: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Andreas%20Goette&per-page=1
# [ID Error] Jian Du: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Jian%20Du&per-page=1
# [ID Error] Ogan Özsoy: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Ogan%20%C3%96zsoy&per-page=1
# [ID Error] T. F. Eifler: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=T.%20F.%20Eifler&per-page=1
# [ID Error] Hyung‐Min Chung: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Hyung%E2%80%90Min%20Chung&per-page=1
# [ID Error] Fuxi Zhang: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Fuxi%20Zhang&per-page=1
# [ID Error] S. Zsoldos: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=S.%20Zsoldos&per-page=1
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[66], line 80
#      79 futures = {executor.submit(process_author, author): author for author in all_authors}
# ---> 80 for future in as_completed(futures):
#      81     author, h_index = future.result()
#
# File /usr/lib/python3.11/concurrent/futures/_base.py:243, in as_completed(fs, timeout)
#     239         raise TimeoutError(
#     240                 '%d (of %d) futures unfinished' % (
#     241                 len(pending), total_futures))
# --> 243 waiter.event.wait(wait_timeout)
#     245 with waiter.lock:
#
# File /usr/lib/python3.11/threading.py:629, in Event.wait(self, timeout)
#     628 if not signaled:
# --> 629     signaled = self._cond.wait(timeout)
#     630 return signaled
#
# File /usr/lib/python3.11/threading.py:327, in Condition.wait(self, timeout)
#     326 if timeout is None:
# --> 327     waiter.acquire()
#     328     gotit = True
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[66], line 78
#      75 author_hindex = {}
#      77 MAX_WORKERS = 5
# ---> 78 with ThreadPoolExecutor(max_workers=MAX_WORKERS) as executor:
#      79     futures = {executor.submit(process_author, author): author for author in all_authors}
#      80     for future in as_completed(futures):
#
# File /usr/lib/python3.11/concurrent/futures/_base.py:647, in Executor.__exit__(self, exc_type, exc_val, exc_tb)
#     646 def __exit__(self, exc_type, exc_val, exc_tb):
# --> 647     self.shutdown(wait=True)
#     648     return False
#
# File /usr/lib/python3.11/concurrent/futures/thread.py:235, in ThreadPoolExecutor.shutdown(self, wait, cancel_futures)
#     233 if wait:
#     234     for t in self._threads:
# --> 235         t.join()
#
# File /usr/lib/python3.11/threading.py:1119, in Thread.join(self, timeout)
#    1116     raise RuntimeError("cannot join current thread")
#    1118 if timeout is None:
# -> 1119     self._wait_for_tstate_lock()
#    1120 else:
#    1121     # the behavior of a negative timeout isn't documented, but
#    1122     # historically .join(timeout=x) for x<0 has acted as if timeout=0
#    1123     self._wait_for_tstate_lock(timeout=max(timeout, 0))
#
# File /usr/lib/python3.11/threading.py:1139, in Thread._wait_for_tstate_lock(self, block, timeout)
#    1136     return
#    1138 try:
# -> 1139     if lock.acquire(block, timeout):
#    1140         lock.release()
#    1141         self._stop()
#
# KeyboardInterrupt:
# [ID Error] Travis A. Cole: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Travis%20A.%20Cole&per-page=1
# [Works Error] https://openalex.org/A5006687149: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/works?filter=author.id:https://openalex.org/A5006687149&per-page=200
# [ID Error] Shigeo Maruyama: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Shigeo%20Maruyama&per-page=1
# [ID Error] Benno H. ter Kuile: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Benno%20H.%20ter%20Kuile&per-page=1
# [Works Error] https://openalex.org/A5000655439: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/works?filter=author.id:https://openalex.org/A5000655439&per-page=200
# [ID Error] Gregory A. Jicha: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Gregory%20A.%20Jicha&per-page=1
# [ID Error] Hang Wu: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Hang%20Wu&per-page=1
# [ID Error] Christian Vrints: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Christian%20Vrints&per-page=1
# [ID Error] Alexander Draschl: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Alexander%20Draschl&per-page=1
# [ID Error] Tingwei Luo: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Tingwei%20Luo&per-page=1
# [ID Error] A.G. Cocco: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=A.G.%20Cocco&per-page=1
# [ID Error] A. Stewart Fotheringham: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=A.%20Stewart%20Fotheringham&per-page=1
# [ID Error] Kelly A. Dorgan: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Kelly%20A.%20Dorgan&per-page=1
# [ID Error] Derek Aranguren van Egmond: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Derek%20Aranguren%20van%20Egmond&per-page=1
# [Works Error] https://openalex.org/A5043115344: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/works?filter=author.id:https://openalex.org/A5043115344&per-page=200
# [ID Error] Mengyao Wen: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Mengyao%20Wen&per-page=1
# [ID Error] Dongni Li: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Dongni%20Li&per-page=1
# [ID Error] Sibylle Loibl: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Sibylle%20Loibl&per-page=1
# [ID Error] Prashant Kumar: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Prashant%20Kumar&per-page=1
# [ID Error] Cyril Sadowsky: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Cyril%20Sadowsky&per-page=1
# [ID Error] Ian Kennedy: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Ian%20Kennedy&per-page=1
# [ID Error] Francesc Ferrer: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Francesc%20Ferrer&per-page=1
# [ID Error] Shani Paluch–Shimon: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Shani%20Paluch%E2%80%93Shimon&per-page=1
# [Works Error] https://openalex.org/A5004231559: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/works?filter=author.id:https://openalex.org/A5004231559&per-page=200
# [Works Error] https://openalex.org/A5009596203: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/works?filter=author.id:https://openalex.org/A5009596203&per-page=200
# [ID Error] Michael Larkin: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Michael%20Larkin&per-page=1
# [Works Error] https://openalex.org/A5084933406: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/works?filter=author.id:https://openalex.org/A5084933406&per-page=200
# [ID Error] Masashi Chiba: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Masashi%20Chiba&per-page=1
# [ID Error] Ralph Weissleder: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Ralph%20Weissleder&per-page=1
# [ID Error] Islay Mactaggart: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Islay%20Mactaggart&per-page=1
# [ID Error] Stephen W. Marshall: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Stephen%20W.%20Marshall&per-page=1
# [ID Error] Shiyang Chen: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Shiyang%20Chen&per-page=1
# [ID Error] Lei Han: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Lei%20Han&per-page=1
# [Works Error] https://openalex.org/A5100742817: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/works?filter=author.id:https://openalex.org/A5100742817&per-page=200
# [Works Error] https://openalex.org/A5072175419: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/works?filter=author.id:https://openalex.org/A5072175419&per-page=200
# [ID Error] L. Moore: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=L.%20Moore&per-page=1
# [ID Error] Mengsiying Li: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Mengsiying%20Li&per-page=1
# [Works Error] https://openalex.org/A5063311573: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/works?filter=author.id:https://openalex.org/A5063311573&per-page=200
# [ID Error] Scott W. Cunningham: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Scott%20W.%20Cunningham&per-page=1
# [ID Error] Navid Khani: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Navid%20Khani&per-page=1
# [ID Error] Elizabeth C. Wick: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Elizabeth%20C.%20Wick&per-page=1
# [ID Error] Donald P. Schneider: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Donald%20P.%20Schneider&per-page=1
# [ID Error] Jennifer Dykxhoorn: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Jennifer%20Dykxhoorn&per-page=1
# [ID Error] A. J. Bailey: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=A.%20J.%20Bailey&per-page=1
# [ID Error] Pratibha Jangra: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Pratibha%20Jangra&per-page=1
# [ID Error] Alex Krolewski: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Alex%20Krolewski&per-page=1
# [Works Error] https://openalex.org/A5002681207: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/works?filter=author.id:https://openalex.org/A5002681207&per-page=200
# [ID Error] Tadahiro Izutani: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Tadahiro%20Izutani&per-page=1
# [ID Error] Rachana Bhatawdekar: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Rachana%20Bhatawdekar&per-page=1
# [ID Error] Lucia La Mura: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Lucia%20La%20Mura&per-page=1
# [ID Error] Jun-Yan Zhu: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Jun-Yan%20Zhu&per-page=1
# [ID Error] Konstantinos P. Ferentinos: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Konstantinos%20P.%20Ferentinos&per-page=1
# [ID Error] José Francisco Nuño Siles: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Jos%C3%A9%20Francisco%20Nu%C3%B1o%20Siles&per-page=1
# [ID Error] Franklin Bien: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Franklin%20Bien&per-page=1
# [Works Error] https://openalex.org/A5103193790: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/works?filter=author.id:https://openalex.org/A5103193790&per-page=200
# [Works Error] https://openalex.org/A5104053092: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/works?filter=author.id:https://openalex.org/A5104053092&per-page=200
# [Works Error] https://openalex.org/A5027477146: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/works?filter=author.id:https://openalex.org/A5027477146&per-page=200
# [ID Error] Jóhann A. Sigurdsson: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=J%C3%B3hann%20A.%20Sigurdsson&per-page=1
# [Works Error] https://openalex.org/A5108056589: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/works?filter=author.id:https://openalex.org/A5108056589&per-page=200
# [ID Error] Jae Wook Cho: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Jae%20Wook%20Cho&per-page=1
# [ID Error] Ariel Pablos-Méndez: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Ariel%20Pablos-M%C3%A9ndez&per-page=1
# [ID Error] Chulhun Kang: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Chulhun%20Kang&per-page=1
# [ID Error] Jesse C. Seegmiller: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Jesse%20C.%20Seegmiller&per-page=1
# [ID Error] P. Mróz: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=P.%20Mr%C3%B3z&per-page=1
# [Works Error] https://openalex.org/A5101966612: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/works?filter=author.id:https://openalex.org/A5101966612&per-page=200
# [ID Error] Daniel L. Rubin: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Daniel%20L.%20Rubin&per-page=1
# [ID Error] R. Bunker: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=R.%20Bunker&per-page=1
# [ID Error] Juan Luis Cano: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Juan%20Luis%20Cano&per-page=1
# [Works Error] https://openalex.org/A5056108881: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/works?filter=author.id:https://openalex.org/A5056108881&per-page=200
# [ID Error] Steven H. Strogatz: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Steven%20H.%20Strogatz&per-page=1
# [ID Error] Giuseppe Viale: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Giuseppe%20Viale&per-page=1
# [ID Error] Piotr Toczek: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Piotr%20Toczek&per-page=1
# [ID Error] Reem Albilali: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Reem%20Albilali&per-page=1
# [ID Error] Adam Coogan: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Adam%20Coogan&per-page=1
# [ID Error] Lorenz Kuhn: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Lorenz%20Kuhn&per-page=1
# [ID Error] Jonathan B. Foster: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Jonathan%20B.%20Foster&per-page=1
# [ID Error] Xinzhi Wang: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Xinzhi%20Wang&per-page=1
# [ID Error] Daniela Schuster: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Daniela%20Schuster&per-page=1
# [ID Error] Sebastian Haferkamp: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Sebastian%20Haferkamp&per-page=1
# [ID Error] Om Prakash Jena: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Om%20Prakash%20Jena&per-page=1
# [ID Error] Xuerong Luo: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Xuerong%20Luo&per-page=1
# [ID Error] Hao Zeng: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Hao%20Zeng&per-page=1
# [ID Error] Pierre Pluye: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Pierre%20Pluye&per-page=1
# [ID Error] Arthur O. Zalevsky: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Arthur%20O.%20Zalevsky&per-page=1
# [ID Error] Mark De Simone: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Mark%20De%20Simone&per-page=1
# [ID Error] Jinfeng Chen: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Jinfeng%20Chen&per-page=1
# [ID Error] Alexander Rives: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Alexander%20Rives&per-page=1
# [ID Error] Jane Ferguson: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Jane%20Ferguson&per-page=1
# [ID Error] Shalini S. Arya: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Shalini%20S.%20Arya&per-page=1
# [ID Error] Jue Wang: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Jue%20Wang&per-page=1
# [Works Error] https://openalex.org/A5005821516: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/works?filter=author.id:https://openalex.org/A5005821516&per-page=200
# [Works Error] https://openalex.org/A5109447166: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/works?filter=author.id:https://openalex.org/A5109447166&per-page=200
# [ID Error] Joerg Osterrieder: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Joerg%20Osterrieder&per-page=1
# [ID Error] Kannikannan Meena: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Kannikannan%20Meena&per-page=1
# [ID Error] M. G. Benjamin: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=M.%20G.%20Benjamin&per-page=1
# [ID Error] Kay Hamacher: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Kay%20Hamacher&per-page=1
# [ID Error] William C. Dougall: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=William%20C.%20Dougall&per-page=1
# [ID Error] Jingxin Fu: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Jingxin%20Fu&per-page=1
# [ID Error] James J. Mulé: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=James%20J.%20Mul%C3%A9&per-page=1
# [ID Error] Jie Lei: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Jie%20Lei&per-page=1
# [ID Error] Leandros Perivolaropoulos: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Leandros%20Perivolaropoulos&per-page=1
# [ID Error] Zhongli Wang: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Zhongli%20Wang&per-page=1
# [ID Error] Marine Carrasco: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Marine%20Carrasco&per-page=1
# [Works Error] https://openalex.org/A5087266920: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/works?filter=author.id:https://openalex.org/A5087266920&per-page=200
# [ID Error] F. Barone: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=F.%20Barone&per-page=1
# [ID Error] Zhangyuanzhu Liu: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Zhangyuanzhu%20Liu&per-page=1
# [ID Error] Mauro Pieroni: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Mauro%20Pieroni&per-page=1
# [ID Error] Martin R. Stockler: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Martin%20R.%20Stockler&per-page=1
# [ID Error] Johan Ordish: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Johan%20Ordish&per-page=1
# [ID Error] Lance Lochner: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Lance%20Lochner&per-page=1
# [ID Error] James Kennedy: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=James%20Kennedy&per-page=1
# [ID Error] R. Hasty: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=R.%20Hasty&per-page=1
# [ID Error] Hollis Lai: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Hollis%20Lai&per-page=1
# [Works Error] https://openalex.org/A5015946177: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/works?filter=author.id:https://openalex.org/A5015946177&per-page=200
# [ID Error] Deborah S. Hasin: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Deborah%20S.%20Hasin&per-page=1
# [ID Error] Brooke B. Osborne: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Brooke%20B.%20Osborne&per-page=1
# [Works Error] https://openalex.org/A5007299750: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/works?filter=author.id:https://openalex.org/A5007299750&per-page=200
# [ID Error] Vitaliy Ovod: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Vitaliy%20Ovod&per-page=1
# [ID Error] Wyman Brantley: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Wyman%20Brantley&per-page=1
# [ID Error] Andre Esteva: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Andre%20Esteva&per-page=1
# [ID Error] V. S. Varadarajan: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=V.%20S.%20Varadarajan&per-page=1
# [ID Error] Mingbo Wu: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Mingbo%20Wu&per-page=1
# [Works Error] https://openalex.org/A5110184149: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/works?filter=author.id:https://openalex.org/A5110184149&per-page=200
# [ID Error] Walter W. Powell: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Walter%20W.%20Powell&per-page=1
# [Works Error] https://openalex.org/A5084947806: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/works?filter=author.id:https://openalex.org/A5084947806&per-page=200
# [ID Error] Juliet Harvey: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Juliet%20Harvey&per-page=1
# [Works Error] https://openalex.org/A5013471878: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/works?filter=author.id:https://openalex.org/A5013471878&per-page=200
# [ID Error] Jacob A. Bentley: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Jacob%20A.%20Bentley&per-page=1
# [ID Error] Andrew Cowie: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Andrew%20Cowie&per-page=1
# [ID Error] Hongzhi Wang: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Hongzhi%20Wang&per-page=1
# [ID Error] Gregory F. Ball: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Gregory%20F.%20Ball&per-page=1
# [ID Error] Hyunwook Kim: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Hyunwook%20Kim&per-page=1
# [ID Error] Bobo Dang: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Bobo%20Dang&per-page=1
# [ID Error] Rohit Deshpande: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Rohit%20Deshpande&per-page=1
# [ID Error] Benjamin A. Shoemaker: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Benjamin%20A.%20Shoemaker&per-page=1
# [ID Error] Leonardo Cruz de Souza: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Leonardo%20Cruz%20de%20Souza&per-page=1
# [ID Error] Oliver T. Unke: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Oliver%20T.%20Unke&per-page=1
# [ID Error] Tom Dhaene: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Tom%20Dhaene&per-page=1
# [ID Error] John Hardy: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=John%20Hardy&per-page=1
# [ID Error] RoseJ. Randall: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=RoseJ.%20Randall&per-page=1
# [ID Error] Văn Đức Nguyễn: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=V%C4%83n%20%C4%90%E1%BB%A9c%20Nguy%E1%BB%85n&per-page=1
# [ID Error] Bryce B. Reeve: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Bryce%20B.%20Reeve&per-page=1
# [ID Error] Marc Lahaye: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Marc%20Lahaye&per-page=1
# [ID Error] John R. Searle: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=John%20R.%20Searle&per-page=1
# [ID Error] C. Caputo: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=C.%20Caputo&per-page=1
# [ID Error] Ke-Wen Ma: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Ke-Wen%20Ma&per-page=1
# [ID Error] Richard J. Perrin: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Richard%20J.%20Perrin&per-page=1
# [ID Error] Mona G. Flores: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Mona%20G.%20Flores&per-page=1
# [Works Error] https://openalex.org/A5023449487: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/works?filter=author.id:https://openalex.org/A5023449487&per-page=200
# [Works Error] https://openalex.org/A5077659049: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/works?filter=author.id:https://openalex.org/A5077659049&per-page=200
# [ID Error] Fan Ding: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Fan%20Ding&per-page=1
# [ID Error] Benjamin Mills: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Benjamin%20Mills&per-page=1
# [ID Error] Rafael Balart: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Rafael%20Balart&per-page=1
# [ID Error] Murray Rudman: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Murray%20Rudman&per-page=1
# [ID Error] Xianzhang Shi: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Xianzhang%20Shi&per-page=1
# [ID Error] Ilya Sutskever: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Ilya%20Sutskever&per-page=1
# [ID Error] Shu‐Lin Liu: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Shu%E2%80%90Lin%20Liu&per-page=1
# [ID Error] Robin J. Ely: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Robin%20J.%20Ely&per-page=1
# [ID Error] Maria Thor: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Maria%20Thor&per-page=1
# [ID Error] Mark D. Griffiths: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Mark%20D.%20Griffiths&per-page=1
# [ID Error] Chen Tu: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Chen%20Tu&per-page=1
# [ID Error] Ronald Kim: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Ronald%20Kim&per-page=1
# [ID Error] Kazuyuki Nagata: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Kazuyuki%20Nagata&per-page=1
# [ID Error] Andrew J. Kirsch: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Andrew%20J.%20Kirsch&per-page=1
# [ID Error] Huimin Zeng: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Huimin%20Zeng&per-page=1
# [ID Error] Stephanie C. Parks: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Stephanie%20C.%20Parks&per-page=1
# [ID Error] Hui Zhi: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Hui%20Zhi&per-page=1
# [ID Error] Zhiyang Huang: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Zhiyang%20Huang&per-page=1
# [ID Error] Bing Zhang: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Bing%20Zhang&per-page=1
# [ID Error] Ina Park: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Ina%20Park&per-page=1
# [ID Error] Li Yu: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Li%20Yu&per-page=1
# [ID Error] Hsin-Yu Chang: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Hsin-Yu%20Chang&per-page=1
# [ID Error] Xavier Robin: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Xavier%20Robin&per-page=1
# [ID Error] Michael Schudson: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Michael%20Schudson&per-page=1
# [ID Error] R. Blomme: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=R.%20Blomme&per-page=1
# [ID Error] Berit H. Goodge: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Berit%20H.%20Goodge&per-page=1
# [ID Error] He Wang: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=He%20Wang&per-page=1
# [ID Error] M. Kaneko: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=M.%20Kaneko&per-page=1
# [ID Error] Yan Li: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Yan%20Li&per-page=1
# [ID Error] Heng-Chao Li: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Heng-Chao%20Li&per-page=1
# [ID Error] Anton V. Baranikov: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Anton%20V.%20Baranikov&per-page=1
# [ID Error] Jonathan M. DuBois: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Jonathan%20M.%20DuBois&per-page=1
# [ID Error] Benjamin F. Mann: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Benjamin%20F.%20Mann&per-page=1
# [ID Error] Els D. Bakker: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Els%20D.%20Bakker&per-page=1
# [Works Error] https://openalex.org/A5014275726: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/works?filter=author.id:https://openalex.org/A5014275726&per-page=200
# [ID Error] Ermete Antolini: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Ermete%20Antolini&per-page=1
# [ID Error] Judit Balázs: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Judit%20Bal%C3%A1zs&per-page=1
# [Works Error] https://openalex.org/A5004862239: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/works?filter=author.id:https://openalex.org/A5004862239&per-page=200
# [ID Error] Mikko Karttunen: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Mikko%20Karttunen&per-page=1
# [ID Error] Z. Reiner: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Z.%20Reiner&per-page=1
# [ID Error] Xin-Heng Guo: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Xin-Heng%20Guo&per-page=1
# [ID Error] Doug Tischer: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Doug%20Tischer&per-page=1
# [ID Error] Deng Pan: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Deng%20Pan&per-page=1
# [ID Error] Pol Van Dorpe: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Pol%20Van%20Dorpe&per-page=1
# [ID Error] Ryan Whaley: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Ryan%20Whaley&per-page=1
# [ID Error] J. Selsing: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=J.%20Selsing&per-page=1
# [Works Error] https://openalex.org/A5107536876: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/works?filter=author.id:https://openalex.org/A5107536876&per-page=200
# [Works Error] https://openalex.org/A5027631951: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/works?filter=author.id:https://openalex.org/A5027631951&per-page=200
# [ID Error] Oleg Emelyanov: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Oleg%20Emelyanov&per-page=1
# [ID Error] Padmanee Sharma: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Padmanee%20Sharma&per-page=1
# [ID Error] C. Bentler: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=C.%20Bentler&per-page=1
# [ID Error] Tingting Yang: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Tingting%20Yang&per-page=1
# [ID Error] Oliver Hahn: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Oliver%20Hahn&per-page=1
# [ID Error] Jingyi Cui: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Jingyi%20Cui&per-page=1
# [ID Error] Aleksandra Jancovic: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Aleksandra%20Jancovic&per-page=1
# [ID Error] Li-Yuan Yang: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Li-Yuan%20Yang&per-page=1
# [ID Error] Rayne Liu: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Rayne%20Liu&per-page=1
# [ID Error] Yidi J. Turman: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Yidi%20J.%20Turman&per-page=1
# [ID Error] Yuanzhi Li: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Yuanzhi%20Li&per-page=1
# [ID Error] Claudia Cicognola: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Claudia%20Cicognola&per-page=1
# [ID Error] Aurélien Le Bail: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Aur%C3%A9lien%20Le%20Bail&per-page=1
# [ID Error] Katerina Georgiou: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Katerina%20Georgiou&per-page=1
# [ID Error] M. Gustafsson: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=M.%20Gustafsson&per-page=1
# [ID Error] S. Boissier: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=S.%20Boissier&per-page=1
# [ID Error] Huixi Dong: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Huixi%20Dong&per-page=1
# [ID Error] Christina Caso: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Christina%20Caso&per-page=1
# [ID Error] Cheuk Hin Ho: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Cheuk%20Hin%20Ho&per-page=1
# [ID Error] Heidi Vandebosch: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Heidi%20Vandebosch&per-page=1
# [Works Error] https://openalex.org/A5019230707: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/works?filter=author.id:https://openalex.org/A5019230707&per-page=200
# [Works Error] https://openalex.org/A5056527871: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/works?filter=author.id:https://openalex.org/A5056527871&per-page=200
# [Works Error] https://openalex.org/A5036717342: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/works?filter=author.id:https://openalex.org/A5036717342&per-page=200
# [Works Error] https://openalex.org/A5106792916: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/works?filter=author.id:https://openalex.org/A5106792916&per-page=200
# [ID Error] Leland McInnes: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Leland%20McInnes&per-page=1
# [ID Error] Tamara Weiss: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Tamara%20Weiss&per-page=1
# [ID Error] Kenta Hotokezaka: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Kenta%20Hotokezaka&per-page=1
# [ID Error] Zengran Wang: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Zengran%20Wang&per-page=1
# [ID Error] Deepak Iyer: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Deepak%20Iyer&per-page=1
# [ID Error] Tianyue Wang: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Tianyue%20Wang&per-page=1
# [ID Error] Dianxu Ren: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Dianxu%20Ren&per-page=1
# [ID Error] David T. Jones: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=David%20T.%20Jones&per-page=1
# [ID Error] Chang Gon Kim: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Chang%20Gon%20Kim&per-page=1
# [Works Error] https://openalex.org/A5042535330: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/works?filter=author.id:https://openalex.org/A5042535330&per-page=200
# [ID Error] Chunhui Ma: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Chunhui%20Ma&per-page=1
# [ID Error] Parinya Punpongsanon: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Parinya%20Punpongsanon&per-page=1
# [ID Error] Ling Liu: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Ling%20Liu&per-page=1
# [ID Error] Daniel G. MacArthur: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Daniel%20G.%20MacArthur&per-page=1
# [ID Error] Dirk Schadendorf: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Dirk%20Schadendorf&per-page=1
# [ID Error] Pierfranco Conté: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Pierfranco%20Cont%C3%A9&per-page=1
# [ID Error] Xinlin Xu: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Xinlin%20Xu&per-page=1
# [Works Error] https://openalex.org/A5014788373: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/works?filter=author.id:https://openalex.org/A5014788373&per-page=200
# [Works Error] https://openalex.org/A5014348196: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/works?filter=author.id:https://openalex.org/A5014348196&per-page=200
# [Works Error] https://openalex.org/A5083459216: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/works?filter=author.id:https://openalex.org/A5083459216&per-page=200
# [Works Error] https://openalex.org/A5100710172: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/works?filter=author.id:https://openalex.org/A5100710172&per-page=200
# [ID Error] Tian Zhu Li: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Tian%20Zhu%20Li&per-page=1
# [ID Error] Bin Zhou: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Bin%20Zhou&per-page=1
# [ID Error] Michał Grochowski: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Micha%C5%82%20Grochowski&per-page=1
# [ID Error] Nina Thiessen: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Nina%20Thiessen&per-page=1
# [ID Error] V. B. Adya: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=V.%20B.%20Adya&per-page=1
# [ID Error] Alok Kumar Paul: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Alok%20Kumar%20Paul&per-page=1
# [ID Error] C. G. Bernhard: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=C.%20G.%20Bernhard&per-page=1
# [ID Error] Suzette Brémault‐Phillips: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Suzette%20Br%C3%A9mault%E2%80%90Phillips&per-page=1
# [ID Error] Dong Young Jeong: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Dong%20Young%20Jeong&per-page=1
# [Works Error] https://openalex.org/A5059793455: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/works?filter=author.id:https://openalex.org/A5059793455&per-page=200
# [ID Error] Sharon L. Lohr: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Sharon%20L.%20Lohr&per-page=1
# [ID Error] R. Rébolo: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=R.%20R%C3%A9bolo&per-page=1
# [ID Error] Agnieszka Jagiełło-Gruszfeld: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Agnieszka%20Jagie%C5%82%C5%82o-Gruszfeld&per-page=1
# [ID Error] Yuehua Huang: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Yuehua%20Huang&per-page=1
# [ID Error] Amal Babour: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Amal%20Babour&per-page=1
# [ID Error] Misha Sra: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Misha%20Sra&per-page=1
# [ID Error] Wei Zhou: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Wei%20Zhou&per-page=1
# [ID Error] Valentin Blomer: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Valentin%20Blomer&per-page=1
# [ID Error] Heyi Li: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Heyi%20Li&per-page=1
# [ID Error] J. Kenneth Salisbury: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=J.%20Kenneth%20Salisbury&per-page=1
# [ID Error] Julian Freigang: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Julian%20Freigang&per-page=1
# [ID Error] Robert Fox: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Robert%20Fox&per-page=1
# ...
# [Works Error] https://openalex.org/A5101924641: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/works?filter=author.id:https://openalex.org/A5101924641&per-page=200
# [ID Error] Francisco J. Jiménez‐Hornero: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Francisco%20J.%20Jim%C3%A9nez%E2%80%90Hornero&per-page=1
# [ID Error] Yanyu Chen: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Yanyu%20Chen&per-page=1
# [ID Error] O. Birnholtz: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=O.%20Birnholtz&per-page=1
# [ID Error] Jessica Young: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Jessica%20Young&per-page=1
# [ID Error] Niraj K. Jha: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Niraj%20K.%20Jha&per-page=1
# [ID Error] R. O’Shaughnessy: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=R.%20O%E2%80%99Shaughnessy&per-page=1
# [ID Error] J. F. Glicenstein: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=J.%20F.%20Glicenstein&per-page=1
# [ID Error] Richard Wormald: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Richard%20Wormald&per-page=1
# [ID Error] D. Contreras: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=D.%20Contreras&per-page=1
# [ID Error] Jane Li: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Jane%20Li&per-page=1
# [ID Error] David G. Bear: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=David%20G.%20Bear&per-page=1
# [ID Error] Hyojung Park: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Hyojung%20Park&per-page=1
# [ID Error] Paul V. Braun: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Paul%20V.%20Braun&per-page=1
# [ID Error] Sergi G. Costafreda: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Sergi%20G.%20Costafreda&per-page=1
# [ID Error] James P. O’Callaghan: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=James%20P.%20O%E2%80%99Callaghan&per-page=1
# [ID Error] Xinli Hu: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Xinli%20Hu&per-page=1
# [ID Error] Sheri‐Michelle Koopowitz: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Sheri%E2%80%90Michelle%20Koopowitz&per-page=1
# [ID Error] Matthew Arentz: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Matthew%20Arentz&per-page=1
# [ID Error] Gang Guo: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Gang%20Guo&per-page=1
# [ID Error] Seoksu Hong: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Seoksu%20Hong&per-page=1
# [Works Error] https://openalex.org/A5050066824: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/works?filter=author.id:https://openalex.org/A5050066824&per-page=200
# [Works Error] https://openalex.org/A5102887325: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/works?filter=author.id:https://openalex.org/A5102887325&per-page=200
# [Works Error] https://openalex.org/A5010236766: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/works?filter=author.id:https://openalex.org/A5010236766&per-page=200
# [ID Error] Lei Song: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Lei%20Song&per-page=1
# [ID Error] Elias Fernando Berra: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Elias%20Fernando%20Berra&per-page=1
# [ID Error] Jing Liu: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Jing%20Liu&per-page=1
# [ID Error] Xiaoqing Gu: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Xiaoqing%20Gu&per-page=1
# [ID Error] Mohd Rosli Mohd Hasan: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Mohd%20Rosli%20Mohd%20Hasan&per-page=1
# [ID Error] Kun Qin: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Kun%20Qin&per-page=1
# [ID Error] Joweria Nakaseegu: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Joweria%20Nakaseegu&per-page=1
# [ID Error] Ying Xue: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Ying%20Xue&per-page=1
# [Works Error] https://openalex.org/A5073759577: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/works?filter=author.id:https://openalex.org/A5073759577&per-page=200
# [Works Error] https://openalex.org/A5074616594: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/works?filter=author.id:https://openalex.org/A5074616594&per-page=200
# [ID Error] Gary Clayton Anderson: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Gary%20Clayton%20Anderson&per-page=1
# [ID Error] Marina Dauar-Tedeschi: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Marina%20Dauar-Tedeschi&per-page=1
# [ID Error] Rouzbeh Allahverdi: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Rouzbeh%20Allahverdi&per-page=1
# [ID Error] M. José Diez: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=M.%20Jos%C3%A9%20Diez&per-page=1
# [ID Error] Giovanni de Girolamo: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Giovanni%20de%20Girolamo&per-page=1
# [ID Error] Nilüfer Ertekin‐Taner: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Nil%C3%BCfer%20Ertekin%E2%80%90Taner&per-page=1
# [ID Error] Julius Kühne: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Julius%20K%C3%BChne&per-page=1
# [ID Error] Christopher K. M. Hui: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Christopher%20K.%20M.%20Hui&per-page=1
# [ID Error] X.C. Zhang: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=X.C.%20Zhang&per-page=1
# [Works Error] https://openalex.org/A5111830579: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/works?filter=author.id:https://openalex.org/A5111830579&per-page=200
# [ID Error] Shi Lv: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Shi%20Lv&per-page=1
# [ID Error] Minghui Lu: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Minghui%20Lu&per-page=1
# [ID Error] Norm Foster: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Norm%20Foster&per-page=1
# [Works Error] https://openalex.org/A5070613056: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/works?filter=author.id:https://openalex.org/A5070613056&per-page=200
# [ID Error] Woo Mi Ryu: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Woo%20Mi%20Ryu&per-page=1
# [ID Error] T. S. Kisner: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=T.%20S.%20Kisner&per-page=1
# [ID Error] Silvia Barbon: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Silvia%20Barbon&per-page=1
# [ID Error] Shaoshi Guo: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Shaoshi%20Guo&per-page=1
# [ID Error] Emanuele Messina: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Emanuele%20Messina&per-page=1
# [ID Error] Weidong Li: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Weidong%20Li&per-page=1
# [ID Error] Yu Wan: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Yu%20Wan&per-page=1
# [ID Error] Luke Burnett: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Luke%20Burnett&per-page=1
# [Works Error] https://openalex.org/A5022904028: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/works?filter=author.id:https://openalex.org/A5022904028&per-page=200
# [ID Error] Kathleen A. Fitzgerald: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Kathleen%20A.%20Fitzgerald&per-page=1
# [Works Error] https://openalex.org/A5058755438: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/works?filter=author.id:https://openalex.org/A5058755438&per-page=200
# [ID Error] Kathleen L. Poston: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Kathleen%20L.%20Poston&per-page=1
# [ID Error] Geoffrey I. N. Waterhouse: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Geoffrey%20I.%20N.%20Waterhouse&per-page=1
# [ID Error] Tim L. T. Wiegand: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Tim%20L.%20T.%20Wiegand&per-page=1
# [ID Error] Udayan Khurana: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Udayan%20Khurana&per-page=1
# [ID Error] Kevin Eaton: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Kevin%20Eaton&per-page=1
# [ID Error] Matteo Aleotti: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Matteo%20Aleotti&per-page=1
# [ID Error] Thomas J. Rothenberg: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Thomas%20J.%20Rothenberg&per-page=1
# [Works Error] https://openalex.org/A5107828088: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/works?filter=author.id:https://openalex.org/A5107828088&per-page=200
# [ID Error] Jesse Minshall: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Jesse%20Minshall&per-page=1
# [ID Error] Rui Luo: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Rui%20Luo&per-page=1
# [ID Error] Christopher J. Armitage: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Christopher%20J.%20Armitage&per-page=1
# [ID Error] Tariq Mahmood: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Tariq%20Mahmood&per-page=1
# [ID Error] Robert T. Chang: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Robert%20T.%20Chang&per-page=1
# [ID Error] Wenguang Tu: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Wenguang%20Tu&per-page=1
# [ID Error] Chaoyun Zhang: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Chaoyun%20Zhang&per-page=1
# [ID Error] Bruno Assuncao: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Bruno%20Assuncao&per-page=1
# [Works Error] https://openalex.org/A5019709911: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/works?filter=author.id:https://openalex.org/A5019709911&per-page=200
# [ID Error] Mamadou Diop: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Mamadou%20Diop&per-page=1
# [ID Error] Felix Richter: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Felix%20Richter&per-page=1
# [Works Error] https://openalex.org/A5102721182: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/works?filter=author.id:https://openalex.org/A5102721182&per-page=200
# [Works Error] https://openalex.org/A5039227022: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/works?filter=author.id:https://openalex.org/A5039227022&per-page=200
# [ID Error] Susmita Sur‐Kolay: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Susmita%20Sur%E2%80%90Kolay&per-page=1
# [ID Error] Aubrey Medrano: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Aubrey%20Medrano&per-page=1
# [ID Error] Mengmeng Jia: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Mengmeng%20Jia&per-page=1
# [ID Error] Qibin Xia: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Qibin%20Xia&per-page=1
# [ID Error] Oleksandr Polozov: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Oleksandr%20Polozov&per-page=1
# [ID Error] Jishen Zhao: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Jishen%20Zhao&per-page=1
# [ID Error] G D Rabinovici: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=G%20D%20Rabinovici&per-page=1
# [ID Error] Wei Guo: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Wei%20Guo&per-page=1
# [Works Error] https://openalex.org/A5102824148: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/works?filter=author.id:https://openalex.org/A5102824148&per-page=200
# [ID Error] Vimal K. Shrivastava: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Vimal%20K.%20Shrivastava&per-page=1
# [ID Error] Julia Amann: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Julia%20Amann&per-page=1
# [ID Error] Elizabeth R. Duval: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Elizabeth%20R.%20Duval&per-page=1
# [ID Error] Tarek Sahmoud: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Tarek%20Sahmoud&per-page=1
# [ID Error] Arpan Kumar Kar: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Arpan%20Kumar%20Kar&per-page=1
# [ID Error] Maarten Sap: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Maarten%20Sap&per-page=1
# [ID Error] Rachel A. Elphinston: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Rachel%20A.%20Elphinston&per-page=1
# [ID Error] H. Van Brussel: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=H.%20Van%20Brussel&per-page=1
# [ID Error] Tianda Fu: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Tianda%20Fu&per-page=1
# [ID Error] Siham Tabik: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Siham%20Tabik&per-page=1
# [Works Error] https://openalex.org/A5012339002: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/works?filter=author.id:https://openalex.org/A5012339002&per-page=200
# [ID Error] Jiani Ding: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Jiani%20Ding&per-page=1
# [Works Error] https://openalex.org/A5109057189: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/works?filter=author.id:https://openalex.org/A5109057189&per-page=200
# [ID Error] Rasim Eren Cankurtaran: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Rasim%20Eren%20Cankurtaran&per-page=1
# [ID Error] Elena G Bignami: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Elena%20G%20Bignami&per-page=1
# [ID Error] A Rosado-Marin: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=A%20Rosado-Marin&per-page=1
# [ID Error] Jerry M. Melillo: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Jerry%20M.%20Melillo&per-page=1
# [ID Error] Shreya Anand: 429 Client Error: TOO MANY REQUESTS for url: https://api.openalex.org/authors?search=Shreya%20Anand&per-page=1

# %%
"""
This script compares the scientific quality of venues cited in real bibliographies versus AI-generated bibliographies.

It uses the SCImago Journal Rank (SJR) dataset to assign a quality score to each venue (journal or conference) mentioned 
in the bibliographies. The bibliographies are loaded from a JSONL file containing both real and generated references.

Main steps:
1. Load the SCImago dataset containing venue titles and their SJR scores.
2. Load bibliographic metadata with lists of venues from both real and generated bibliographies.
3. Extract venue names and map them to SCImago titles using fuzzy matching to handle minor name differences.
4. Retrieve the corresponding SJR scores for each matched venue.
5. Visualize and compare the distributions of SJR scores between real and generated bibliographies.
6. Perform a Mann-Whitney U test to assess if there is a statistically significant difference in venue quality 
   between real and generated citations.

This analysis helps evaluate whether AI-generated bibliographies cite venues of similar scientific influence compared 
to real bibliographies.
"""

import os
import json
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import mannwhitneyu
from difflib import get_close_matches

# Set a clean style for seaborn plots
sns.set(style="whitegrid")

# Filename for the SCImago dataset (adjust path or filename if needed)
SJR_FILENAME = "scimagojr 2024.csv"

# Check if the SCImago file exists before proceeding
if not os.path.isfile(SJR_FILENAME):
    raise FileNotFoundError(f"File {SJR_FILENAME} not found. Please check the filename and path.")

# Load the SCImago data depending on the file extension
if SJR_FILENAME.endswith(".csv"):
    # The dataset uses semicolons as separators and commas as decimals; encoding is latin1
    sjr_df = pd.read_csv(SJR_FILENAME, sep=';', decimal=',', encoding="latin1")
elif SJR_FILENAME.endswith(".xlsx") or SJR_FILENAME.endswith(".xls"):
    # Excel file loading
    sjr_df = pd.read_excel(SJR_FILENAME)
else:
    raise ValueError("Unsupported file format for SCImago data. Use CSV or Excel.")

# Print column names to understand dataset structure, then keep only relevant columns
print("Columns in SCImago data:", sjr_df.columns.tolist())
sjr_df = sjr_df[['Title', 'SJR']].dropna()  # Keep only 'Title' and 'SJR' columns and drop missing values

# Clean venue titles by stripping extra whitespace
sjr_df['Title'] = sjr_df['Title'].str.strip()

# Load the JSONL file containing bibliographies metadata
# Each line corresponds to an entry with real and generated bibliographies
with open("full_bibliography_metadata_qwen_3.jsonl", "r", encoding="utf-8") as f:
    results = [json.loads(line) for line in f]

# Function to extract venues from a list of references
def extract_venues(bibliographies):
    venues = []
    for ref in bibliographies:
        # Extract the venue field if present and known
        v = ref.get('venue')
        # Filter out unknown or empty venues
        if v and v.lower() != 'unknown venue':
            venues.append(v.strip())
    return venues

# Initialize lists to hold all venues from real and generated bibliographies
real_venues = []
gen_venues = []

# Extract venues from all entries in the dataset
for entry in results:
    # Extend lists with venues from real and generated bibliographies
    real_venues.extend(extract_venues(entry.get('real_bibliography', [])))
    gen_venues.extend(extract_venues(entry.get('generated_bibliography', [])))

# Function to map a given venue name to the closest SCImago title using fuzzy matching
def map_venue_to_sjr(venue, sjr_titles):
    # get_close_matches returns a list of close matches with a similarity cutoff threshold
    matches = get_close_matches(venue, sjr_titles, n=1, cutoff=0.7)
    # Return the best match or None if no match passes the cutoff
    return matches[0] if matches else None

# Extract the list of SCImago titles for matching
sjr_titles = sjr_df['Title'].tolist()

# Function to get SJR scores for a list of venues, counting how many could not be matched
def get_sjr_score_for_venues(venues):
    scores = []
    no_match_count = 0
    for v in venues:
        matched_title = map_venue_to_sjr(v, sjr_titles)
        if matched_title:
            # Retrieve the SJR score for the matched title
            score = sjr_df.loc[sjr_df['Title'] == matched_title, 'SJR'].values[0]
            scores.append(score)
        else:
            # Increment count of unmatched venues
            no_match_count += 1
    print(f"Could not match {no_match_count} out of {len(venues)} venues.")
    return scores

# Get SJR scores for venues in real and generated bibliographies
real_sjr_scores = get_sjr_score_for_venues(real_venues)
gen_sjr_scores = get_sjr_score_for_venues(gen_venues)

# Print summary of how many scores were collected
print(f"Real SJR scores collected: {len(real_sjr_scores)}")
print(f"Generated SJR scores collected: {len(gen_sjr_scores)}")

# Print mean and standard deviation for quick statistical overview
print(f"Real bibliography SJR scores: mean = {np.mean(real_sjr_scores):.4f}, std = {np.std(real_sjr_scores):.4f}")
print(f"Generated bibliography SJR scores: mean = {np.mean(gen_sjr_scores):.4f}, std = {np.std(gen_sjr_scores):.4f}")

# Plot histograms + KDE of the SJR score distributions for both groups
plt.figure(figsize=(12, 6))

# Define bin edges spanning the combined range of scores
bins = np.linspace(min(min(real_sjr_scores), min(gen_sjr_scores)),
                   max(max(real_sjr_scores), max(gen_sjr_scores)), 40)

# Plot real bibliography SJR distribution in blue
sns.histplot(real_sjr_scores, bins=bins, kde=True, stat='density',
             label='Real bibliography', color='blue', alpha=0.5)

# Plot generated bibliography SJR distribution in orange
sns.histplot(gen_sjr_scores, bins=bins, kde=True, stat='density',
             label='Generated bibliography', color='orange', alpha=0.5)

plt.xlim((0, 50))  # Limit x-axis to focus on typical SJR ranges
plt.xlabel('SCImago Journal Rank (SJR)')
plt.ylabel('Density')
plt.title('Distribution of SCImago Journal Rank (SJR) Scores')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# Statistical test: Mann-Whitney U test to compare the two independent samples
stat, p_value = mannwhitneyu(real_sjr_scores, gen_sjr_scores, alternative='two-sided')

print(f"Mann-Whitney U test statistic: {stat}")
print(f"P-value: {p_value:.4f}")

# Interpret results based on p-value threshold (0.05)
if p_value < 0.05:
    print("Significant difference in SJR score distributions between real and generated bibliography venues.")
else:
    print("No significant difference found in SJR score distributions between real and generated bibliography venues.")
# Out:
# Columns in SCImago data: ['Rank', 'Sourceid', 'Title', 'Type', 'Issn', 'SJR', 'SJR Best Quartile', 'H index', 'Total Docs. (2024)', 'Total Docs. (3years)', 'Total Refs.', 'Total Citations (3years)', 'Citable Docs. (3years)', 'Citations / Doc. (2years)', 'Ref. / Doc.', '%Female', 'Overton', 'SDG', 'Country', 'Region', 'Publisher', 'Coverage', 'Categories', 'Areas']
# Could not match 650 out of 7600 venues.
# Could not match 101 out of 539 venues.
# Real SJR scores collected: 6950
# Generated SJR scores collected: 438
# Real bibliography SJR scores: mean = 3.2987, std = 4.7282
# Generated bibliography SJR scores: mean = 4.8142, std = 6.1482
# Mann-Whitney U test statistic: 1378027.0
# P-value: 0.0009
# Significant difference in SJR score distributions between real and generated bibliography venues.

# %%
"""
This script analyzes geographic biases in citations between real and AI-generated bibliographies.

It loads bibliographic metadata where each entry contains country-level citation distributions 
for both real and generated references.

Main steps:
1. Load the metadata JSONL file containing real and generated country citation counts.
2. Aggregate the citation counts per country for both real and generated datasets.
3. Calculate smoothed frequencies of citations by country to avoid zero counts in later computations.
4. Compute the log base 2 ratio (log2 bias) of generated vs. real citation frequencies per country.
5. Resolve country names to standard ISO country names using the 'pycountry' library for consistency.
6. Cap extreme bias values to improve visualization clarity.
7. Plot a choropleth world map visualizing the log2 bias per country using Plotly Express.

This visualization helps identify countries that are over- or under-represented in AI-generated bibliographies 
compared to real bibliographies, providing insights into geographic biases in citation generation.
"""

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pycountry
import plotly.express as px
from collections import Counter
import json

# Load full bibliographic metadata from JSONL file
with open("full_bibliography_metadata_qwen_3.jsonl", "r", encoding="utf-8") as f:
    # Read each line and parse JSON only if line is not empty
    data = [json.loads(line) for line in f if line.strip()]

# Initialize counters to accumulate citation counts by country
real_country_counter = Counter()
gen_country_counter = Counter()
total_real_refs = 0
total_gen_refs = 0

# Aggregate country citation counts across all metadata entries
for entry in data:
    # Safely access country distributions for real and generated bibliographies
    real_dist = entry.get("real_analysis", {}).get("country_distribution", {})
    gen_dist = entry.get("generated_analysis", {}).get("country_distribution", {})
    
    # Update the global counters with the counts from this entry
    real_country_counter.update(real_dist)
    gen_country_counter.update(gen_dist)
    
    # Track total counts to calculate frequencies later
    total_real_refs += sum(real_dist.values())
    total_gen_refs += sum(gen_dist.values())

# Determine minimum non-zero frequency in both real and generated data for smoothing
min_real_freq = min(v/total_real_refs for v in real_country_counter.values() if v > 0)
min_gen_freq = min(v/total_gen_refs for v in gen_country_counter.values() if v > 0)
# Set smoothing factor to a small fraction of the smallest frequency to avoid zero division
smoothing_factor = min(min_real_freq, min_gen_freq) / 100

bias_data = []
# Combine all countries seen in either dataset
all_countries = set(real_country_counter) | set(gen_country_counter)

# Calculate smoothed frequencies and log2 bias for each country
for country in all_countries:
    real_count = real_country_counter.get(country, 0)
    gen_count = gen_country_counter.get(country, 0)
    
    # Apply smoothing to counts and total to prevent division by zero
    real_freq = (real_count + smoothing_factor) / (total_real_refs + smoothing_factor * len(all_countries))
    gen_freq = (gen_count + smoothing_factor) / (total_gen_refs + smoothing_factor * len(all_countries))
    
    # Compute log2 ratio of generated frequency to real frequency
    log2_bias = np.log2(gen_freq / real_freq)
    
    # Attempt to standardize country name using pycountry's lookup
    try:
        iso_name = pycountry.countries.lookup(country).name
    except LookupError:
        # If no match found, keep original country string
        iso_name = country

    # Append dictionary of bias info for this country
    bias_data.append({
        "country": iso_name,
        "bias_log2_gen_vs_real": log2_bias,
        "real_freq": real_freq,
        "gen_freq": gen_freq,
        "raw_real_count": real_count,
        "raw_gen_count": gen_count
    })

# Convert list of dictionaries into a DataFrame for easier manipulation and plotting
bias_df = pd.DataFrame(bias_data)

# Clip extreme bias values to [-3, 3] to avoid distortion in color scale visualization
max_bias = 3
bias_df['bias_log2_gen_vs_real'] = bias_df['bias_log2_gen_vs_real'].clip(-max_bias, max_bias)

# Create an interactive choropleth map using Plotly Express
fig = px.choropleth(
    bias_df,
    locations="country",              # Country names for location
    locationmode="country names",    # Use country names to locate countries on the map
    color="bias_log2_gen_vs_real",   # Color scale based on log2 bias values
    color_continuous_scale="RdBu",   # Red-Blue diverging scale (red = overrepresented, blue = underrepresented)
    range_color=[-max_bias, max_bias],  # Fix color scale range for consistency
    title="Geographic Bias in Generated vs. Real Bibliographies (log₂ scale)",
    labels={"bias_log2_gen_vs_real": "log₂ Bias"},
    hover_data=["real_freq", "gen_freq", "raw_real_count", "raw_gen_count"]  # Additional info on hover
)

# Improve map aesthetics by showing coastlines and setting projection type
fig.update_geos(showcoastlines=True, projection_type="equirectangular")
# Remove default margins for better fit
fig.update_layout(margin={"r":0,"t":40,"l":0,"b":0})

# Display the interactive map
fig.show()
